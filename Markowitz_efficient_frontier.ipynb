# %%
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2021,2,1)
end = datetime.datetime(2022,2,1)

# %%
tata_steel = pd.DataFrame() 
try:
    # download the stock price 
    stock = []
    stock = yf.download('TATASTEEL.NS',start=start, end=end, progress=False)
        
    # append the individual stock prices 
    if len(stock) == 0:
        None
    else:
        stock['Name']='TATASTEEL.NS'
        tata_steel = tata_steel.append(stock,sort=False)
except Exception:
    None
tata_steel
# Out:
#                    Open         High          Low        Close   Adj Close  \
# Date
# 2021-02-01   604.900024   640.000000   597.450012   636.099976  558.947388
# 2021-02-02   643.000000   648.000000   624.099976   641.650024  563.824219
# 2021-02-03   644.900024   664.299988   637.250000   653.150024  573.929443
# 2021-02-04   654.000000   663.500000   638.599976   655.950012  576.389771
# 2021-02-05   656.900024   690.599976   651.400024   685.049988  601.960266
# ...                 ...          ...          ...          ...         ...
# 2022-01-24  1160.000000  1163.650024  1090.000000  1099.199951  987.492737
# 2022-01-25  1094.699951  1121.000000  1087.050049  1109.099976  996.386658
# 2022-01-27  1090.000000  1103.449951  1061.300049  1088.349976  977.745422
# 2022-01-28  1105.849976  1125.750000  1080.949951  1084.650024  974.421387
# 2022-01-31  1109.900024  1114.599976  1080.500000  1085.550049  975.230042
#
#               Volume          Name
# Date
# 2021-02-01  21084694  TATASTEEL.NS
# 2021-02-02  18048957  TATASTEEL.NS
# 2021-02-03  14846381  TATASTEEL.NS
# 2021-02-04  14764995  TATASTEEL.NS
# 2021-02-05  29100888  TATASTEEL.NS
# ...              ...           ...
# 2022-01-24   8392076  TATASTEEL.NS
# 2022-01-25   5733063  TATASTEEL.NS
# 2022-01-27   9056656  TATASTEEL.NS
# 2022-01-28   7864893  TATASTEEL.NS
# 2022-01-31   5570939  TATASTEEL.NS
#
# [248 rows x 7 columns]

# %%
aurobindo_pharma = pd.DataFrame()
try:
    # download the stock price 
    stock = []
    stock = yf.download('AUROPHARMA.NS',start=start, end=end, progress=False)
        
    # append the individual stock prices 
    if len(stock) == 0:
        None
    else:
        stock['Name']='AUROPHARMA.NS'
        aurobindo_pharma = aurobindo_pharma.append(stock,sort=False)
except Exception:
    None
aurobindo_pharma
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-01  912.000000  926.950012  889.000000  921.450012  906.096802
# 2021-02-02  929.000000  938.900024  910.599976  921.599976  906.244202
# 2021-02-03  921.599976  948.750000  916.950012  920.000000  904.670837
# 2021-02-04  921.799988  935.799988  912.200012  927.150024  911.701843
# 2021-02-05  932.000000  954.900024  925.000000  942.849976  927.140137
# ...                ...         ...         ...         ...         ...
# 2022-01-24  655.450012  655.450012  603.349976  609.700012  603.163635
# 2022-01-25  609.700012  621.599976  590.099976  616.849976  610.236938
# 2022-01-27  616.849976  618.950012  594.000000  608.799988  602.273254
# 2022-01-28  619.200012  638.000000  612.400024  623.900024  617.211426
# 2022-01-31  634.000000  644.950012  625.299988  634.450012  627.648254
#
#              Volume           Name
# Date
# 2021-02-01  2096640  AUROPHARMA.NS
# 2021-02-02  2692863  AUROPHARMA.NS
# 2021-02-03  4755801  AUROPHARMA.NS
# 2021-02-04  1881897  AUROPHARMA.NS
# 2021-02-05  4131354  AUROPHARMA.NS
# ...             ...            ...
# 2022-01-24  3355188  AUROPHARMA.NS
# 2022-01-25  3015220  AUROPHARMA.NS
# 2022-01-27  3349451  AUROPHARMA.NS
# 2022-01-28  2307397  AUROPHARMA.NS
# 2022-01-31  1561664  AUROPHARMA.NS
#
# [248 rows x 7 columns]

# %%
hdfc_bank = pd.DataFrame()
try:
    # download the stock price 
    stock = []
    stock = yf.download('HDFCBANK.NS',start=start, end=end, progress=False)
        
    # append the individual stock prices 
    if len(stock) == 0:
        None
    else:
        stock['Name']='HDFCBANK.NS'
        hdfc_bank = hdfc_bank.append(stock,sort=False)
except Exception:
    None
hdfc_bank
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-02-01  1410.250000  1482.500000  1401.000000  1476.750000  1453.486450
# 2021-02-02  1501.000000  1578.500000  1497.400024  1560.550049  1535.966309
# 2021-02-03  1579.000000  1581.699951  1542.000000  1574.800049  1549.991943
# 2021-02-04  1566.000000  1588.000000  1543.449951  1579.099976  1554.224121
# 2021-02-05  1548.000000  1618.250000  1548.000000  1597.599976  1572.432617
# ...                 ...          ...          ...          ...          ...
# 2022-01-24  1509.949951  1521.250000  1467.550049  1486.650024  1469.563354
# 2022-01-25  1458.650024  1495.000000  1444.000000  1488.050049  1470.947266
# 2022-01-27  1450.000000  1485.000000  1435.000000  1474.949951  1457.997803
# 2022-01-28  1477.500000  1486.699951  1460.000000  1463.250000  1446.432251
# 2022-01-31  1472.750000  1491.550049  1466.800049  1485.699951  1468.624268
#
#               Volume         Name
# Date
# 2021-02-01  13185272  HDFCBANK.NS
# 2021-02-02  21210103  HDFCBANK.NS
# 2021-02-03  10118627  HDFCBANK.NS
# 2021-02-04  12242342  HDFCBANK.NS
# 2021-02-05  13527358  HDFCBANK.NS
# ...              ...          ...
# 2022-01-24   5934254  HDFCBANK.NS
# 2022-01-25   6797124  HDFCBANK.NS
# 2022-01-27  14308919  HDFCBANK.NS
# 2022-01-28  12462604  HDFCBANK.NS
# 2022-01-31   6421273  HDFCBANK.NS
#
# [248 rows x 7 columns]

# %%
stocks=pd.concat([tata_steel['Close'],aurobindo_pharma['Close'],hdfc_bank['Close']],axis=1)
stocks.columns=['tata_steel','aurobindo_pharma','hdfc_bank']
stocks
# Out:
#              tata_steel  aurobindo_pharma    hdfc_bank
# Date
# 2021-02-01   636.099976        921.450012  1476.750000
# 2021-02-02   641.650024        921.599976  1560.550049
# 2021-02-03   653.150024        920.000000  1574.800049
# 2021-02-04   655.950012        927.150024  1579.099976
# 2021-02-05   685.049988        942.849976  1597.599976
# ...                 ...               ...          ...
# 2022-01-24  1099.199951        609.700012  1486.650024
# 2022-01-25  1109.099976        616.849976  1488.050049
# 2022-01-27  1088.349976        608.799988  1474.949951
# 2022-01-28  1084.650024        623.900024  1463.250000
# 2022-01-31  1085.550049        634.450012  1485.699951
#
# [248 rows x 3 columns]

# %%
returns=stocks/stocks.shift(1)
returns
# Out:
#             tata_steel  aurobindo_pharma  hdfc_bank
# Date
# 2021-02-01         NaN               NaN        NaN
# 2021-02-02    1.008725          1.000163   1.056746
# 2021-02-03    1.017923          0.998264   1.009131
# 2021-02-04    1.004287          1.007772   1.002730
# 2021-02-05    1.044363          1.016934   1.011716
# ...                ...               ...        ...
# 2022-01-24    0.939728          0.930201   0.977031
# 2022-01-25    1.009007          1.011727   1.000942
# 2022-01-27    0.981291          0.986950   0.991196
# 2022-01-28    0.996600          1.024803   0.992068
# 2022-01-31    1.000830          1.016910   1.015343
#
# [248 rows x 3 columns]

# %%
log_returns=np.log(returns)
log_returns
# Out:
#             tata_steel  aurobindo_pharma  hdfc_bank
# Date
# 2021-02-01         NaN               NaN        NaN
# 2021-02-02    0.008687          0.000163   0.055195
# 2021-02-03    0.017764         -0.001738   0.009090
# 2021-02-04    0.004278          0.007742   0.002727
# 2021-02-05    0.043407          0.016792   0.011647
# ...                ...               ...        ...
# 2022-01-24   -0.062165         -0.072355  -0.023237
# 2022-01-25    0.008966          0.011659   0.000941
# 2022-01-27   -0.018886         -0.013136  -0.008843
# 2022-01-28   -0.003405          0.024500  -0.007964
# 2022-01-31    0.000829          0.016768   0.015226
#
# [248 rows x 3 columns]

# %%
number=10000
log_returns_mean=log_returns.mean()
weight=np.zeros((number,3))
expected_returns=np.zeros((number))
expected_volatility=np.zeros((number))
sharpe_ratio=np.zeros((number))
sigma=log_returns.cov()

# %%
for k in range(number):
    w=np.array(np.random.random(3))
    wn=w/np.sum(w)
    weight[k,:]=wn
    
    expected_returns[k]=np.sum(log_returns_mean*w)
    
    expected_volatility[k]=np.sqrt(np.dot(w.T,np.dot(sigma,w)))
    
    sharpe_ratio[k]=expected_returns[k]/expected_volatility[k]

# %%
max_index=sharpe_ratio.argmax()
print(max_index)
print(sharpe_ratio[max_index])
# Out:
# 6174
# 0.08366337415223699

# %%
plt.figure(figsize=(20,8))
plt.scatter(expected_volatility , expected_returns,c=sharpe_ratio)
plt.xlabel('expected volatility')
plt.ylabel('expected log return')
plt.title('Markowitz Frontier of my Portfolio')
plt.colorbar(label='Sharpe Ratio')
plt.scatter(expected_volatility[max_index], expected_returns[max_index],c='red')
plt.show()

# %%
print("The money shold be distributed in following ration between the 'TATASTEEL.NS', 'AUROPHARMA.NS' and 'HDFCBANK' respectively:",weight[max_index,0],":",weight[max_index,1],":",weight[max_index,2])
# Out:
# The money shold be distributed in following ration between the 'TATASTEEL.NS', 'AUROPHARMA.NS' and 'HDFCBANK' respectively: 0.9818076159091302 : 0.013846254343485607 : 0.004346129747384148
